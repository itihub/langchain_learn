# %% [markdown]
# ## CrewAI 安装与第一个示例
#
# + 安装
# + 第一个示例

# %% [markdown]
# ### 安装前置条件
#
# + python >= 3.10 and < 3.13

# %%
! python --version
# Out:
# Python 3.12.11

# %%
# uv安装
! pip install uv
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 3.6 MB/s  0:00:06m0:00:0100:01
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# 查看uv
! which uv
# Out:
# /home/jizhe/projects/python/langchain_learn/.venv/bin/uv

# %%
# 安装CrewAI CLI
! uv tool install crewai
# Out:
# Resolved 133 packages in 2m 52s
# ⠴ Preparing packages... (0/85)
# ⠴ Preparing packages... (0/85)------------------     0 B/85.27 KiB
# ⠴ Preparing packages... (0/85)------------------     0 B/85.27 KiB
# websocket-client     ------------------------------     0 B/80.68 KiB
# ⠦ Preparing packages... (0/85)------------------     0 B/85.27 KiB
# websocket-client     ------------------------------     0 B/80.68 KiB
# ⠦ Preparing packages... (0/85)------------------     0 B/85.27 KiB
# websocket-client     ------------------------------     0 B/80.68 KiB
# ⠦ Preparing packages... (0/85)------------------ 14.87 KiB/85.27 KiB
# websocket-client     ------------------------------ 14.87 KiB/80.68 KiB
# ⠦ Preparing packages... (0/85)------------------ 14.87 KiB/85.27 KiB
# websocket-client     ------------------------------ 14.87 KiB/80.68 KiB
# ⠦ Preparing packages... (0/85)------------------ 14.87 KiB/85.27 KiB
# websocket-client     ------------------------------ 14.87 KiB/80.68 KiB
# ...

# %%
# 验证安装
! uv tool list

# %% [markdown]
# ### 第一个示例
#
# + 使用脚手架搭建

# %%
! crewai create crew hello-world

# %%
# 进入生成好的项目并安装依赖
! cd hello-world && crewai install --active

# %%
# 运行项目
! crewai run
