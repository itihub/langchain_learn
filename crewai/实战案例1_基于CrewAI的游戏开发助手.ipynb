# %% [markdown]
# ### 使用手脚架生成项目

# %%
# 安装CrewAI CLI
! uv tool install crewai
# Out:
# `crewai` is already installed

# %%
! crewai create crew game_builder_crew
# Out:
# /bin/bash: line 1: crewai: command not found

# %% [markdown]
# ### 运行项目

# %%
# 安装依赖
! cd game_builder_crew && poetry install

# %%
# 运行项目
! cd game_builder_crewai && uv run game_builder_crew
