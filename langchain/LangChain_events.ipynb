# %% [markdown]
# ## 加载环境变量

# %%
import os
from dotenv import load_dotenv

# 加载 .env 文件中的环境变量
load_dotenv(override=True)  # 使用 override=True 确保加载最新的 .env 数据
# Out:
# True

# %% [markdown]
# ## LangChain 可执行组件的基本调用方式(Runnable 核心方法)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=os.environ.get("OPENAPI_MODEL"),
    base_url=os.environ.get("OPENAPI_API_BASE"),
    api_key=os.environ.get("OPENAPI_API_KEY"),
    temperature=0,
)

question = "LangChain是什么？"

# %% [markdown]
# ### invoke(): 同步执行一个 Runnable

# %%
llm.invoke(question)
# Out:
# AIMessage(content='LangChain 是一个用于构建基于大语言模型（LLM）应用的开发框架，旨在帮助开发者更高效地利用语言模型的能力，结合外部数据和工具，创建功能丰富的应用程序。以下是关于 LangChain 的详细介绍：\n\n---\n\n### **1. 核心功能**\n- **连接语言模型与其他组件**：  \n  将LLM（如GPT、Claude等）与外部数据源、API、数据库等集成，扩展模型的能力。\n- **模块化设计**：  \n  提供可组合的模块（如模型调用、记忆管理、工具使用等），简化开发流程。\n- **支持多种应用场景**：  \n  如问答系统、聊天机器人、文本生成、数据分析等。\n\n---\n\n### **2. 关键组件**\n- **Models**：支持多种LLM提供商（OpenAI、Anthropic、Hugging Face等）。\n- **Prompts**：优化提示词（Prompt）设计，支持模板化、动态提示。\n- **Chains**：将多个步骤组合成工作流（例如：调用模型→处理输出→调用API）。\n- **Agents**：让模型自主选择工具（如搜索、计算、代码执行）完成任务。\n- **Memory**：管理对话历史或上下文，实现多轮交互。\n- **Indexes**：集成外部数据（文档、数据库），支持检索增强生成（RAG）。\n\n---\n\n### **3. 典型应用场景**\n- **检索增强生成（RAG）**：  \n  从自定义数据源（如PDF、数据库）中提取信息，生成更精准的回答。\n- **自主Agent**：  \n  模型通过调用工具（如搜索引擎、Python解释器）完成复杂任务。\n- **对话系统**：  \n  构建有记忆能力的聊天机器人，支持个性化交互。\n- **自动化流程**：  \n  如自动生成报告、数据分析、代码辅助等。\n\n---\n\n### **4. 代码示例（Python）**\n```python\nfrom langchain_openai import ChatOpenAI\nfrom langchain_core.prompts import ChatPromptTemplate\n\n# 初始化模型\nllm = ChatOpenAI(model="gpt-3.5-turbo")\n\n# 定义提示模板\nprompt = ChatPromptTemplate.from_template("用中文回答：{question}")\n\n# 创建简单链\nchain = prompt | llm\n\n# 调用链\nresponse = chain.invoke({"question": "LangChain是什么？"})\nprint(response.content)\n```\n\n---\n\n### **5. 优势**\n- **灵活性**：支持自定义模块和扩展。\n- **生态丰富**：提供大量预构建工具（如文档加载器、向量数据库集成）。\n- **社区支持**：活跃的开发者社区和持续更新。\n\n---\n\n### **6. 学习资源**\n- 官方文档：[https://python.langchain.com](https://python.langchain.com)\n- GitHub仓库：[https://github.com/langchain-ai/langchain](https://github.com/langchain-ai/langchain)\n- 教程：LangChain提供快速入门指南和示例代码库。\n\n---\n\nLangChain 适合需要将LLM与实际业务逻辑结合的开发者，能显著降低开发复杂AI应用的难度。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 659, 'prompt_tokens': 7, 'total_tokens': 666, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'deepseek-v3-250324', 'system_fingerprint': None, 'id': '0217566948724020353c1c00ae0c96712374521cc0112bb62033d', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2852416c-da95-4947-82c7-9940ec5b7d57-0', usage_metadata={'input_tokens': 7, 'output_tokens': 659, 'total_tokens': 666, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})

# %% [markdown]
# ### stream(): 流式生成响应，通常用于实时显示文本。

# %%
for chunk in llm.stream(question):
    print(chunk.content, end="|", flush=True)
# Out:
# Lang|Chain| |是一个|用于|构建|基于|大型|语言|模型|（|LL|M|）|的|应用程序|的开|源|框架|。|它|由| Harrison| Chase| |于| |202|2| |年|推出|，|旨在|简化|语言|模型|在实际|应用|中的|集成|和|扩展|。|以下是| Lang|Chain| |的核心|概念|和|功能|：
#
# |---
#
# |###| **|1|.| |核心|功能|**
# |-| **|模块|化|设计|**|：|提供|标准化|接口|，|方便|连接|不同|组件|（|如|语言|模型|、|数据|源|、|工具|等|）。
# |-| **|链|式|调用|（|Ch|ains|）|**|：|将|多个|步骤|组合|成|工作|流|（|例如|：|调用|模型| →| |处理|输出| →| |调用|外部| API|）。
# |-| **|上下文|管理|**|：|支持|长期|记忆|（|如|聊天|历史|）|和|短期|上下文|（|当前|会话|）。
# |-| **|工具|集成|**|：|允许|模型|与|外部|工具|（|搜索|、|计算|、|数据库|等|）|交互|，|增强|实用性|。
#
# |---
#
# |###| **|2|.| |主要|组件|**
# |-| **|Models|**|：|支持|多种| LL|M|（|如| OpenAI|、|An|throp|ic|、|H|ug|ging| Face| |等|）|和|嵌入|模型|。
# |-| **|Prom|pts|**|：|管理|提示|模板|，|支持|动态|内容|注入|。
# |-| **|Memory|**|：|存储|对话|历史|或|应用|状态|（|如| `|Convers|ation|Buffer|Memory|`|）。
# |-| **|Index|es|**|：|连接|外部|数据|（|文档|、|数据库|），|支持|检索|增强|生成|（|R|AG|）。
# |-| **|Ag|ents|**|：|让|模型|自主|选择|工具|完成任务|（|类似|自主|决策|的| AI| |代理|）。
#
# |---
#
# |###| **|3|.| |典型|应用|场景|**
# |-| **|问答|系统|**|：|基于|文档|的|智能|问答|（|R|AG|）。
# |-| **|聊天|机器人|**|：|支持|多|轮|对话|和|上下文|记忆|。
# |-| **|数据|增强|应用|**|：|结合|数据库|或| API| |生成|动态|内容|。
# |-| **|自动化|流程|**|：|如|自动|生成|报告|、|代码|分析|等|。
#
# |---
#
# |###| **|4|.| |代码|示例|（|Python|）|**
# |```|python|
# |from| lang|chain|.|ll|ms| import| OpenAI|
# |from| lang|chain|.ch|ains| import| LL|M|Chain|
# |from| lang|chain|.p|rom|pts| import| Prompt|Template|
#
# |#| |初始化|模型|
# |ll|m| =| OpenAI|(model|_name|="|g|pt|-|3|.|5|-t|ur|bo|")
#
# |#| |定义|提示|模板|
# |prom|pt| =| Prompt|Template|(
# |   | input|_v|ariables|=["|product|"],
# |   | template|="|为| {|product|}| |写|一段|广告|文案|，|突出|其|核心|卖|点|。|"
# |)
#
# |#| |创建|链|
# |chain| =| LL|M|Chain|(ll|m|=|ll|m|,| prompt|=|prom|pt|)
#
# |#| |运行|链|
# |result| =| chain|.run|("|智能|手表|")
# |print|(result|)
# |```
#
# |---
#
# |###| **|5|.| |优势|与|挑战|**
# |-| **|优势|**|：
# | | -| |快速|原型|开发|，|减少|底层|代码|。
# | | -| |支持|多种| LL|M| |和|外部|工具|。
# | | -| |活跃|的|开发者|社区|和|持续|更新|。
# |-| **|挑战|**|：
# | | -| |复杂|链|式|调用|可能|需|调试|。
# | | -| |依赖|外部| API| |时|需|处理|延迟|和|成本|。
#
# |---
#
# |###| **|6|.| |生态系统|扩展|**
# |-| **|Lang|Serve|**|：|将|链|部署|为| API|。
# |-| **|Lang|Smith|**|：|调试|和|监控|工具|（|由| Lang|Chain| |官方|提供|）。
# |-| |集成|向量|数据库|（|如| Pine|cone|、|We|av|iate|）|增强|检索|能力|。
#
# |---|
#
# |如果你|计划|使用| Lang|Chain|，|建议|从|[|官方|文档|](|https|://|python|.lang|chain|.com|/)|开始|，|并结合|具体|场景|（|如| R|AG| |或| Agent| |开发|）|深入学习|。||

# %% [markdown]
# ### batch(): 批量处理多个输入，常用于提高并行处理效率。

# %%
llm.batch(["LangChain作者是谁？", "LangChain的竞品有哪些？"])
# Out:
# [AIMessage(content='LangChain 是由 **Harrison Chase** 创建的。他于 2022 年 10 月首次开源发布了 LangChain 项目，旨在帮助开发者更高效地构建基于大型语言模型（LLM）的应用程序。LangChain 提供了模块化工具和组件，支持链式调用、记忆管理、代理（agents）等功能，成为 AI 开发领域的重要工具之一。\n\nHarrison Chase 此前在机器学习与自然语言处理领域有丰富经验，LangChain 的迅速流行也与他及团队对开发者生态的重视密切相关。目前，LangChain 已发展为一个活跃的开源社区，并有商业公司提供支持。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 134, 'prompt_tokens': 8, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'deepseek-v3-250324', 'system_fingerprint': None, 'id': '0217564594548840fa6ef8c2347680bd87fd8d357bb16f17f6304', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--49d1ff36-8749-4e0c-b0a5-7f873835fa4c-0', usage_metadata={'input_tokens': 8, 'output_tokens': 134, 'total_tokens': 142, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#  AIMessage(content='LangChain 作为构建大语言模型（LLM）应用的重要框架，确实存在多个竞品，它们在功能定位、使用场景或技术架构上有重叠或替代性。以下是主要的竞品分类和代表性工具：\n\n---\n\n### **1. 通用型 LLM 应用开发框架**\n- **LlamaIndex**  \n  - 专注于数据的索引和检索（RAG场景），提供高效的非结构化数据处理能力，常与 LangChain 结合使用，但也可独立替代 LangChain 的检索部分。\n  - 优势：轻量级、检索优化，适合知识密集型应用。\n\n- **Semantic Kernel（微软）**  \n  - 微软推出的框架，支持多模态和规划式任务编排，深度集成 Azure OpenAI 服务。  \n  - 优势：与微软生态无缝兼容，适合企业级 Azure 用户。\n\n- **Haystack（Deepset）**  \n  - 专注于问答系统和文档检索，提供管道式（Pipeline）设计，支持多种数据库和模型。  \n  - 优势：模块化强，适合构建复杂的问答系统。\n\n- **AutoGen（微软）**  \n  - 支持多智能体（Multi-Agent）协作，通过自动化工作流简化复杂任务。  \n  - 优势：适合需要多角色交互的场景（如模拟会议、自动化测试）。\n\n---\n\n### **2. 低代码/无代码平台**\n- **Flowise / Langflow**  \n  - 提供可视化界面，通过拖拽组件构建 LLM 流程，底层依赖 LangChain。  \n  - 优势：快速原型开发，适合非技术用户。\n\n- **Dust**  \n  - 企业级工作流设计工具，支持自定义 AI 助手和数据处理。  \n  - 优势：团队协作和权限管理完善。\n\n---\n\n### **3. 特定场景优化工具**\n- **Fixie**  \n  - 专注于企业级 AI 代理开发，强调与业务系统的集成（如 CRM、ERP）。  \n  - 优势：面向生产环境，支持复杂 API 调用。\n\n- **CrewAI**  \n  - 基于多智能体协作的框架，类似 AutoGen，但更注重任务分解和角色分配。  \n  - 优势：适合自动化流程（如爬虫、数据分析）。\n\n---\n\n### **4. 基础设施层竞品**\n- **PromptFlow（微软）**  \n  - 覆盖从提示工程到部署的全生命周期管理，集成在 Azure ML 中。  \n  - 优势：企业级 MLOps 支持。\n\n- **Vercel AI SDK**  \n  - 提供现成的 UI 组件和 API 封装，简化 LLM 应用的前后端开发。  \n  - 优势：适合快速部署 Web 应用。\n\n---\n\n### **5. 新兴开源替代品**\n- **Embedchain**  \n  - 专注于简化 RAG 应用开发，内置多数据源支持（YouTube、PDF 等）。  \n  - 优势：极简 API，适合快速实现检索增强生成。\n\n- **GPT4All**  \n  - 本地化运行 LLM 的工具链，可与 LangChain 配合使用或替代部分功能。  \n  - 优势：隐私保护，离线运行。\n\n---\n\n### **选择建议**\n- **需要复杂链式逻辑** → LangChain 或 Semantic Kernel  \n- **专注检索（RAG）** → LlamaIndex 或 Haystack  \n- **快速可视化开发** → Flowise / Langflow  \n- **企业级部署** → PromptFlow 或 Fixie  \n- **多智能体协作** → AutoGen 或 CrewAI  \n\n这些工具并非完全互斥，实际开发中常组合使用（如 LangChain + LlamaIndex）。竞品的成熟度、社区支持和商业集成（如云厂商绑定）也是关键考量因素。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 10, 'total_tokens': 806, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'deepseek-v3-250324', 'system_fingerprint': None, 'id': '02175645945493296db84678096855c914576ee293efb9dce4eb0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--bf62bce7-c44f-4a29-8b21-ab649cd1e7ca-0', usage_metadata={'input_tokens': 10, 'output_tokens': 796, 'total_tokens': 806, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]

# %% [markdown]
# ### astream_events(): 异步流式传输事件，用于接收更丰富的中间步骤信息，比如工具调用或链的中间状态。

# %%
async for event in llm.astream_events(question, version="v2"):
    print(f"event={event['event']} | name={event['name']} | data={event['data']}")
# Out:
# event=on_chat_model_start | name=ChatOpenAI | data={'input': 'langchain是什么？'}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='是一个', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='用于', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='构建', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='基于', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='大型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='语言', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='LL', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='M', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='应用程序', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='开源', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='框架', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='旨在', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='帮助', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='开发者', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='更', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='高效', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='地', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='开发', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='部署', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='和', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='扩展', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='基于', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' AI', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='对话', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='系统', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='问答', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='系统', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='智能', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='代理', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='等', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='应用', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='它', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='通过', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模块', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='化', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='设计', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='将', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='语言', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='与其他', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='工具', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='数据', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='源', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='和', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='业务流程', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='连接', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='起来', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='简化', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='了', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='复杂', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='应用的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='开发', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='流程', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='---\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='核心', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='功能', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='与', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='特点', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模块', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='化', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='设计', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' Lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='提供', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='了一系列', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='可', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='组合', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='组件', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='如', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='提示', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模板', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='记忆', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='机制', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='数据', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='检索', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='工具', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='等', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='），', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='开发者', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='可以', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='灵活', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='搭配', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='这些', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模块', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='构建', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='应用', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='支持', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='多种', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='语言', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='兼容', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' OpenAI', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='An', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='throp', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ic', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='H', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ug', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ging', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' Face', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='等', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='主流', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' LL', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='M', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='也', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='支持', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='本地', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='部署', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='如', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' Ll', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ama', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='GPT', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='All', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）。\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='数据', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='增强', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='R', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='AG', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' Retrie', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='val', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='-Aug', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='mented', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' Generation', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='支持', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='从', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='外部', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='数据', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='源', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='如', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='文档', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='数据库', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='、', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='API', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='检索', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='信息', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='并将其', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='注入', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='到', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='提示', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='中', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='提升', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='回答', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='准确', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='性和', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='时效', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='性', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='记忆', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Memory', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='管理', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='可', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='跟踪', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='对话', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='历史', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='或', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='用户', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='状态', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='实现', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='多', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='轮', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='对话', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='上下文', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='感知', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='代理', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Ag', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ents', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='）', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='系统', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='允许', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='动态', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# ...
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='://', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='python', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.com', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='](', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='https', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='://', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='python', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.com', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=')\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' GitHub', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='仓库', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='：[', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='https', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='://', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='github', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.com', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='/lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ai', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='/lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='](', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='https', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='://', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='github', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='.com', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='/lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='ai', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='/lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=')\n\n', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Lang', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='Chain', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='适合', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='需要', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='快速', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='构建', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='复杂', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' LL', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='M', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='应用的', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='场景', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='但', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='若', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='需求', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='简单', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='（', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='如', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='单', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='次', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='对话', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='），', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='直接', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='调用', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='模型', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' API', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='可能', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='更', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='轻', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='量', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='。', additional_kwargs={}, response_metadata={}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_stream | name=ChatOpenAI | data={'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'deepseek-v3-250324', 'service_tier': 'default'}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}
# event=on_chat_model_end | name=ChatOpenAI | data={'output': AIMessageChunk(content='LangChain 是一个用于构建基于大型语言模型（LLM）的应用程序的**开源框架**，旨在帮助开发者更高效地开发、部署和扩展基于 AI 的对话系统、问答系统、智能代理等应用。它通过模块化设计，将语言模型与其他工具、数据源和业务流程连接起来，简化了复杂应用的开发流程。\n\n---\n\n### **核心功能与特点**\n1. **模块化设计**  \n   LangChain 提供了一系列可组合的组件（如模型、提示模板、记忆机制、数据检索工具等），开发者可以灵活搭配这些模块构建应用。\n\n2. **支持多种语言模型**  \n   兼容 OpenAI、Anthropic、Hugging Face 等主流 LLM，也支持本地部署的模型（如 Llama 2、GPT-4All）。\n\n3. **数据增强（RAG, Retrieval-Augmented Generation）**  \n   支持从外部数据源（如文档、数据库、API）检索信息，并将其注入到模型提示中，提升回答的准确性和时效性。\n\n4. **记忆（Memory）管理**  \n   可跟踪对话历史或用户状态，实现多轮对话的上下文感知。\n\n5. **代理（Agents）系统**  \n   允许模型动态调用工具（如计算器、搜索引擎、代码执行环境），完成复杂任务（例如：“查天气后生成诗歌”）。\n\n6. **多语言支持**  \n   虽然主要用 Python 实现，但社区也提供了 JavaScript/TypeScript 版本（LangChain.js）。\n\n---\n\n### **典型应用场景**\n- **问答机器人**：基于文档或知识库的智能问答。\n- **自动化流程**：如自动生成报告、邮件处理。\n- **代码辅助**：解释代码、生成单元测试。\n- **数据分析**：连接数据库或 API，用自然语言查询数据。\n\n---\n\n### **简单代码示例**\n```python\nfrom langchain_community.llms import OpenAI\nfrom langchain.prompts import PromptTemplate\n\n# 初始化模型\nllm = OpenAI(model_name="gpt-3.5-turbo")\n\n# 定义提示模板\nprompt = PromptTemplate(\n    input_variables=["topic"],\n    template="用中文简单解释一下 {topic} 是什么？"\n)\n\n# 运行链式调用\nquestion = prompt.format(topic="量子计算")\nresponse = llm(question)\nprint(response)\n```\n\n---\n\n### **与类似工具的区别**\n- **相比直接调用 OpenAI API**：LangChain 提供了更高层次的抽象（如记忆、工具链），避免重复造轮子。\n- **相比 AutoGPT**：LangChain 更注重开发灵活性，而非端到端自动化。\n\n---\n\n### **学习资源**\n- 官方文档：[https://python.langchain.com](https://python.langchain.com)\n- GitHub 仓库：[https://github.com/langchain-ai/langchain](https://github.com/langchain-ai/langchain)\n\nLangChain 适合需要快速构建复杂 LLM 应用的场景，但若需求简单（如单次对话），直接调用模型 API 可能更轻量。', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'deepseek-v3-250324', 'service_tier': 'default'}, id='run--d1ca40cd-2cfb-462f-b0d1-eebfeefb0c87')}

# %% [markdown]
# ### with_structured_output()
# 影响LLM的输出，以结构化的数据来输出而不是字符串
# - 将 LLM 的输出强制转换为结构化格式（如 JSON）。它返回一个带有输出解析器（Output Parser）的新 Runnable。

# %% [markdown]
# #### 定义数据格式

# %%
from pydantic import BaseModel, Field
from typing import Optional
from typing_extensions import Annotated, TypedDict


# 定义 Pydantic 模型
class Joke(BaseModel):
    setup: str = Field(description="The setup of the joke")
    punchline: str = Field(description="The punchline of the joke")
    rating: Optional[int] = Field(
        default=None, description="The rating of the joke from 1 to 10", ge=1, le=10
    )


# 定义字典结构
class Joke2(TypedDict):
    setup: Annotated[str, "The setup of the joke"]
    punchline: Annotated[str, "The punchline of the joke"]
    rating: Annotated[Optional[int], None, "The rating of the joke from 1 to 10"]

# %% [markdown]
# #### 将LLM输出转换 Pydantic 模型

# %%
# 绑定输出格式
structured_llm = llm.with_structured_output(Joke)

# structured_llm_with_prompt = llm.with_structured_output(Joke, method="json_mode")
# system_message = structured_llm_with_prompt.invoke("")
# print(system_message)

joke_instance = structured_llm.invoke("给我讲一个关于程序员的笑话", {"verbose": True})

print("--- LLM 的原始返回 ---")
# print(joke_instance.content)
print("-----------------------")

# # Print the model instance directly
print(joke_instance)

# # Convert the model to a dictionary
# joke_dict = joke_instance.model_dump()
# print(joke_dict)

# # Convert the model to a JSON string
# joke_json = joke_instance.model_dump_json(indent=4)
# print(joke_json)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[46], line 8
#       2 structured_llm = llm.with_structured_output(Joke)
#       4 # structured_llm_with_prompt = llm.with_structured_output(Joke, method="json_mode")
#       5 # system_message = structured_llm_with_prompt.invoke("")
#       6 # print(system_message)
# ----> 8 joke_instance = structured_llm.invoke("给我讲一个关于程序员的笑话", {"verbose": True})
#      10 print("--- LLM 的原始返回 ---")
#      11 # print(joke_instance.content)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045 with set_config_context(config) as context:
#    3046     if i == 0:
# -> 3047         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3048     else:
#    3049         input_ = context.run(step.invoke, input_, config)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1183, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1181     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1182         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1183     raise e
#    1184 if (
#    1185     self.include_response_headers
#    1186     and raw_response is not None
#    1187     and hasattr(raw_response, "headers")
#    1188 ):
#    1189     generation_info = {"headers": dict(raw_response.headers)}
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1155, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1149 try:
#    1150     raw_response = (
#    1151         self.root_client.chat.completions.with_raw_response.parse(
#    1152             **payload
#    1153         )
#    1154     )
# -> 1155     response = raw_response.parse()
#    1156 except openai.BadRequestError as e:
#    1157     _handle_openai_bad_request(e)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:139, in LegacyAPIResponse.parse(self, to)
#     137 parsed = self._parse(to=to)
#     138 if is_given(self._options.post_parser):
# --> 139     parsed = self._options.post_parser(parsed)
#     141 if isinstance(parsed, BaseModel):
#     142     add_request_id(parsed, self.request_id)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:177, in Completions.parse.<locals>.parser(raw_completion)
#     176 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
# --> 177     return _parse_chat_completion(
#     178         response_format=response_format,
#     179         chat_completion=raw_completion,
#     180         input_tools=chat_completion_tools,
#     181     )
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/lib/_parsing/_completions.py:146, in parse_chat_completion(response_format, input_tools, chat_completion)
#     136             else:
#     137                 tool_calls.append(tool_call)
#     139     choices.append(
#     140         construct_type_unchecked(
#     141             type_=cast(Any, ParsedChoice)[solve_response_format_t(response_format)],
#     142             value={
#     143                 **choice.to_dict(),
#     144                 "message": {
#     145                     **message.to_dict(),
# --> 146                     "parsed": maybe_parse_content(
#     147                         response_format=response_format,
#     148                         message=message,
#     149                     ),
#     150                     "tool_calls": tool_calls if tool_calls else None,
#     151                 },
#     152             },
#     153         )
#     154     )
#     156 return cast(
#     157     ParsedChatCompletion[ResponseFormatT],
#     158     construct_type_unchecked(
#    (...)    164     ),
#     165 )
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/lib/_parsing/_completions.py:199, in maybe_parse_content(response_format, message)
#     193 def maybe_parse_content(
#     194     *,
#     195     response_format: type[ResponseFormatT] | ResponseFormatParam | NotGiven,
#     196     message: ChatCompletionMessage | ParsedChatCompletionMessage[object],
#     197 ) -> ResponseFormatT | None:
#     198     if has_rich_response_format(response_format) and message.content and not message.refusal:
# --> 199         return _parse_content(response_format, message.content)
#     201     return None
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/lib/_parsing/_completions.py:262, in _parse_content(response_format, content)
#     260 def _parse_content(response_format: type[ResponseFormatT], content: str) -> ResponseFormatT:
#     261     if is_basemodel_type(response_format):
# --> 262         return cast(ResponseFormatT, model_parse_json(response_format, content))
#     264     if is_dataclass_like_type(response_format):
#     265         if not PYDANTIC_V2:
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/openai/_compat.py:169, in model_parse_json(model, data)
#     167 def model_parse_json(model: type[_ModelT], data: str | bytes) -> _ModelT:
#     168     if PYDANTIC_V2:
# --> 169         return model.model_validate_json(data)
#     170     return model.parse_raw(data)
#
# File ~/projects/python/langchain_learn/.venv/lib/python3.12/site-packages/pydantic/main.py:746, in BaseModel.model_validate_json(cls, json_data, strict, context, by_alias, by_name)
#     740 if by_alias is False and by_name is not True:
#     741     raise PydanticUserError(
#     742         'At least one of `by_alias` or `by_name` must be set to True.',
#     743         code='validate-by-alias-and-name-false',
#     744     )
# --> 746 return cls.__pydantic_validator__.validate_json(
#     747     json_data, strict=strict, context=context, by_alias=by_alias, by_name=by_name
#     748 )
#
# ValidationError: 1 validation error for Joke
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='好的！这是一个经...比较运算符。）', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_invalid

# %%
# 使用未指定输出格式LLM调用，做对比
llm.invoke("给我讲一个关于程序员的笑话")
# Out:
# AIMessage(content='好的！这里有一个经典的程序员笑话：\n\n---\n\n**程序员去超市买东西：**  \n店员问："您要袋子吗？"  \n程序员："要。"  \n店员："您要大的还是小的？"  \n程序员："大的。"  \n店员："您要大号的是吧？"  \n程序员："不是，要大号的。"  \n\n（注：程序员以为店员在问"== 还是 != "，结果陷入了编程逻辑的循环😂）\n\n---\n\n另一个版本：  \n**为什么程序员分不清万圣节和圣诞节？**  \n因为 Oct **31**（八进制31）等于 Dec **25**（十进制25）啊！ 🎃→🎄  \n\n希望你喜欢！ 😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 10, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'deepseek-v3-250324', 'system_fingerprint': None, 'id': '02175669498628595974c45c753025815a93ba93a971603461533', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--00c6fafb-e112-4c70-ab38-e06d50ea0289-0', usage_metadata={'input_tokens': 10, 'output_tokens': 141, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})

# %%
# 结构化输出使用流式输出
structured_llm = llm.with_structured_output(Joke2)

for chunk in structured_llm.stream("给我讲一个关于程序员的笑话"):
    print(chunk)
